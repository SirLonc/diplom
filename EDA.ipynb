# %%
import pandas as pd

# %%
credit_df = pd.read_csv('data/creditcard.csv')
diabetes = pd.read_csv('data/diabetes.csv')
hepatites = pd.read_csv('data/HepatitisCdata.csv', index_col=0)

# %%
hepatites['Category'] = hepatites['Category'].apply(lambda x: int(int(x[0]) > 0))
hepatites['Sex'] = hepatites['Sex'].apply(lambda x: int(x == 'm'))

# %%
hepatites
# Out:
#      Category  Age  Sex   ALB    ALP    ALT    AST   BIL    CHE  CHOL   CREA  \
# 1           0   32    1  38.5   52.5    7.7   22.1   7.5   6.93  3.23  106.0
# 2           0   32    1  38.5   70.3   18.0   24.7   3.9  11.17  4.80   74.0
# 3           0   32    1  46.9   74.7   36.2   52.6   6.1   8.84  5.20   86.0
# 4           0   32    1  43.2   52.0   30.6   22.6  18.9   7.33  4.74   80.0
# 5           0   32    1  39.2   74.1   32.6   24.8   9.6   9.15  4.32   76.0
# ..        ...  ...  ...   ...    ...    ...    ...   ...    ...   ...    ...
# 611         1   62    0  32.0  416.6    5.9  110.3  50.0   5.57  6.30   55.7
# 612         1   64    0  24.0  102.8    2.9   44.4  20.0   1.54  3.02   63.0
# 613         1   64    0  29.0   87.3    3.5   99.0  48.0   1.66  3.63   66.7
# 614         1   46    0  33.0    NaN   39.0   62.0  20.0   3.56  4.20   52.0
# 615         1   59    0  36.0    NaN  100.0   80.0  12.0   9.07  5.30   67.0
#
#        GGT  PROT
# 1     12.1  69.0
# ...

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
credit_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...
